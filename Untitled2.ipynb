# %%
#اول حاجه fine-tuning بستخدام transflow

import tensorflow as tf
from tensorflow.keras import layers, models

# عدد الكلاسات بتاعتك
NUM_CLASSES = 5
IMG_SIZE = 224

# تحميل موديل مدرب مسبقًا
base_model = tf.keras.applications.ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# تجميد الطبقات
base_model.trainable = False

# بناء الموديل الجديد
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# Compile
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# تدريب أولي
history = model.fit(train_dataset, epochs=5, validation_data=val_dataset)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 #اول حاجه fine-tuning بستخدام transflow
# ----> 3 import tensorflow as tf
#       4 from tensorflow.keras import layers, models
#       6 # عدد الكلاسات بتاعتك
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# فك آخر 20 طبقة
base_model.trainable = True

for layer in base_model.layers[:-20]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_fine = model.fit(train_dataset, epochs=10, validation_data=val_dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # فك آخر 20 طبقة
# ----> 2 base_model.trainable = True
#       4 for layer in base_model.layers[:-20]:
#       5     layer.trainable = False
#
# NameError: name 'base_model' is not defined

# %%
# بستخدام pytorch
import torch
import torch.nn as nn
import torchvision.models as models

NUM_CLASSES = 5

# تحميل موديل pretrained
model = models.resnet50(pretrained=True)

# تجميد الطبقات
for param in model.parameters():
    param.requires_grad = False

# استبدال الطبقة الأخيرة
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, NUM_CLASSES)

# نقل للموديل على GPU لو متاح
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Loss & Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.fc.parameters(), lr=1e-4)

# %%
# فك آخر طبقتين
for name, param in model.named_parameters():
    if "layer4" in name:
        param.requires_grad = True

optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-5)
